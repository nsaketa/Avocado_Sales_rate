# %%
import pandas as pd

# %%
data = pd.read_csv('avocado.csv')

# %%
#Output dataset include prices  and sales volume

# consumption on multiple US markets

# %%
print(data.columns) #prints columns name
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
data.dtypes  #prints data types
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
data.isnull().sum()  #checks if anything is null
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
data.describe() #description of all mean,std,etc.
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
data.max()
# Out:
# Unnamed: 0                    52
# Date                  2018-03-25
# AveragePrice                3.25
# Total Volume         6.25056e+07
# 4046                 2.27436e+07
# 4225                 2.04706e+07
# 4770                 2.54644e+06
# Total Bags           1.93731e+07
# Small Bags           1.33846e+07
# Large Bags            5.7191e+06
# XLarge Bags               551694
# type                     organic
# year                        2018
# region          WestTexNewMexico
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
#data[max]. plot(kind='hist', title='Maximum: ')
data.plot(kind='scatter', x='year', y='AveragePrice');

# %%
data.plot(kind='scatter', x='region', y='Total Volume');

# %%
new_data = data[['AveragePrice', 'Total Volume', 'region']]
new_data
# Out:
#        AveragePrice  Total Volume            region
# 0              1.33      64236.62            Albany
# 1              1.35      54876.98            Albany
# 2              0.93     118220.22            Albany
# 3              1.08      78992.15            Albany
# 4              1.28      51039.60            Albany
# ...             ...           ...               ...
# 18244          1.63      17074.83  WestTexNewMexico
# 18245          1.71      13888.04  WestTexNewMexico
# 18246          1.87      13766.76  WestTexNewMexico
# 18247          1.93      16205.22  WestTexNewMexico
# 18248          1.62      17489.58  WestTexNewMexico
#
# [18249 rows x 3 columns]

# %%
new_data=new_data.rename(columns={'Total Volume': 'TotalVolume'})

# %%
new_data.dtypes
# Out:
# AveragePrice    float64
# TotalVolume     float64
# region           object
# dtype: object

# %%
new_data.groupby('region').TotalVolume.mean()
# Out:
# region
# Albany                 4.753787e+04
# Atlanta                2.621453e+05
# BaltimoreWashington    3.985619e+05
# Boise                  4.264257e+04
# Boston                 2.877929e+05
# BuffaloRochester       6.793630e+04
# California             3.044324e+06
# Charlotte              1.051939e+05
# Chicago                3.955690e+05
# CincinnatiDayton       1.317219e+05
# Columbus               8.873776e+04
# DallasFtWorth          6.166251e+05
# Denver                 4.109542e+05
# Detroit                1.876403e+05
# GrandRapids            8.938383e+04
# GreatLakes             1.744505e+06
# HarrisburgScranton     1.236948e+05
# HartfordSpringfield    1.499128e+05
# Houston                6.010884e+05
# Indianapolis           8.953666e+04
# Jacksonville           8.517753e+04
# LasVegas               1.608784e+05
# LosAngeles             1.502653e+06
# Louisville             4.762427e+04
# MiamiFtLauderdale      2.889740e+05
# Midsouth               1.503992e+06
# ...

# %%
new_data.groupby('region').TotalVolume.agg(['count', 'min', 'max', 'mean'])
# Out:
#                      count        min          max          mean
# region
# Albany                 338     774.20    216738.47  4.753787e+04
# Atlanta                338    3047.38    957792.07  2.621453e+05
# BaltimoreWashington    338    6884.09   1225103.27  3.985619e+05
# Boise                  338     562.64    136377.55  4.264257e+04
# Boston                 338    1948.28    999783.13  2.877929e+05
# BuffaloRochester       338     379.82    201142.55  6.793630e+04
# California             338   70004.38  11213596.29  3.044324e+06
# Charlotte              338    2390.22    411160.94  1.051939e+05
# Chicago                338    9910.84   1802646.35  3.955690e+05
# CincinnatiDayton       338    6349.77    538518.77  1.317219e+05
# Columbus               338    2002.61    333398.29  8.873776e+04
# DallasFtWorth          338    6568.67   1885401.44  6.166251e+05
# Denver                 338    6554.93   1381528.74  4.109542e+05
# ...

# %%
new_data.sort_values('TotalVolume', ascending=False).head(10)
# Out:
#       AveragePrice  TotalVolume   region
# 9097          0.87  62505646.52  TotalUS
# 8366          0.77  61034457.10  TotalUS
# 5506          0.76  52288697.89  TotalUS
# 8353          1.09  47293921.60  TotalUS
# 5493          0.82  46324529.70  TotalUS
# 2699          0.89  44655461.51  TotalUS
# 9090          1.03  43409835.75  TotalUS
# 9096          0.97  43167806.09  TotalUS
# 9099          1.08  42939821.55  TotalUS
# 5494          0.84  42867608.54  TotalUS

# %%
new_data.sort_values('TotalVolume', ascending=False).tail(10)
# Out:
#        AveragePrice  TotalVolume             region
# 11719          1.72       561.10           Syracuse
# 13190          1.58       542.85  MiamiFtLauderdale
# 9426           1.93       530.96   BuffaloRochester
# 16201          2.19       515.01   NewOrleansMobile
# 11697          2.07       482.26           Syracuse
# 13193          1.49       472.82  MiamiFtLauderdale
# 11698          2.05       419.98           Syracuse
# 13189          1.58       385.55  MiamiFtLauderdale
# 9437           1.73       379.82   BuffaloRochester
# 10381          1.59        84.56  MiamiFtLauderdale
